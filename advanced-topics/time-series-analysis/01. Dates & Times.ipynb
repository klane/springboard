# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Dates

# %%
rng = pd.date_range('2016 Jul 1', periods = 10, freq = 'D')
rng
# Out:
# DatetimeIndex(['2016-07-01', '2016-07-02', '2016-07-03', '2016-07-04',
#                '2016-07-05', '2016-07-06', '2016-07-07', '2016-07-08',
#                '2016-07-09', '2016-07-10'],
#               dtype='datetime64[ns]', freq='D')

# %% [markdown]
# ## Which of these formats DON'T work?
# '2016 Jul 1', '7/1/2016', '1/7/2016', 'July 1, 2016', '2016-07-01', '2016/07/01'
#
# They all work, though '7/1/2016' and '1/7/2016' produce different dates

# %%
# Is '7/1/2016' in January or July?
# July since it matches the range above
pd.date_range('7/1/2016', periods = 10, freq = 'D')
# Out:
# DatetimeIndex(['2016-07-01', '2016-07-02', '2016-07-03', '2016-07-04',
#                '2016-07-05', '2016-07-06', '2016-07-07', '2016-07-08',
#                '2016-07-09', '2016-07-10'],
#               dtype='datetime64[ns]', freq='D')

# %%
# What is the class of an individual object held in the date_range?
type(rng)
# Out:
# pandas.core.indexes.datetimes.DatetimeIndex

# %% [markdown]
# # Timestamps

# %%
# TIME STAMPS VS TIME SPANS
pd.Timestamp('2016-07-10')
# Out:
# Timestamp('2016-07-10 00:00:00')

# %%
# You can also more details 
pd.Timestamp('2016-07-10 10')
# Out:
# Timestamp('2016-07-10 10:00:00')

# %%
# Or even more...
pd.Timestamp('2016-07-10 10:15')
# Out:
# Timestamp('2016-07-10 10:15:00')

# %%
# How much detail can you add?
pd.Timestamp('2016-07-10 10:15:12.34')
# Out:
# Timestamp('2016-07-10 10:15:12.340000')

# %%
# What are some properties of timestamps? Try them out.
# hint: http://pandas.pydata.org/pandas-docs/stable/timeseries.html#time-date-components
t = pd.Timestamp('2016-07-10 10:15')
t.timetuple()
# Out:
# time.struct_time(tm_year=2016, tm_mon=7, tm_mday=10, tm_hour=10, tm_min=15, tm_sec=0, tm_wday=6, tm_yday=192, tm_isdst=-1)

# %%
(t.year, t.month, t.day)
# Out:
# (2016, 7, 10)

# %%
t.weekofyear
# Out:
# 27

# %% [markdown]
# # Time Spans

# %%
pd.Period('2016-01')
# Out:
# Period('2016-01', 'M')

# %%
# What's that extra info above? How does it get set?
# It is the shortest unit of time represented by the period

# %%
pd.Period('2016-01-01')
# Out:
# Period('2016-01-01', 'D')

# %%
pd.Period('2016-01-01 10')
# Out:
# Period('2016-01-01 10:00', 'H')

# %%
pd.Period('2016-01-01 10:10')
# Out:
# Period('2016-01-01 10:10', 'T')

# %%
pd.Period('2016-01-01 10:10:10')
# Out:
# Period('2016-01-01 10:10:10', 'S')

# %%
# What's the most detailed Period you can get?
pd.Period('2016-01-01 10:10:10.123456')
# Out:
# Period('2016-01-01 10:10:10.123456', 'U')

# %%
# How can you make multiple time periods? 
# Hint look for analogy with pd.date_range() above
pd.period_range('7/1/2016', periods = 10, freq = 'D')
# Out:
# PeriodIndex(['2016-07-01', '2016-07-02', '2016-07-03', '2016-07-04',
#              '2016-07-05', '2016-07-06', '2016-07-07', '2016-07-08',
#              '2016-07-09', '2016-07-10'],
#             dtype='period[D]', freq='D')

# %%
p = pd.Period('July 2016')
t = pd.Timestamp('July 4, 2016')

# %%
p.start_time < t < p.end_time
# Out:
# True

# %% [markdown]
# # Time Offsets

# %%
pd.Timedelta('1 day')
# Out:
# Timedelta('1 days 00:00:00')

# %%
pd.Period('2016-01-01 10:10') + pd.Timedelta('1 day')
# Out:
# Period('2016-01-02 10:10', 'T')

# %%
pd.Timestamp('2016-01-01 10:10') + pd.Timedelta('1 day')
# Out:
# Timestamp('2016-01-02 10:10:00')

# %%
pd.Timestamp('2016-01-01 10:10') + pd.Timedelta('15 ns')
# Out:
# Timestamp('2016-01-01 10:10:00.000000015')

# %% [markdown]
# # Fancy Frequencies

# %%
# FANCY FREQUENCY SETTING
# Only want business days
pd.period_range('2016-01-01 10:10', freq = 'B', periods = 10)
# Out:
# PeriodIndex(['2016-01-01', '2016-01-04', '2016-01-05', '2016-01-06',
#              '2016-01-07', '2016-01-08', '2016-01-11', '2016-01-12',
#              '2016-01-13', '2016-01-14'],
#             dtype='period[B]', freq='B')

# %%
# It's possible to combine frequencies. What if you want to advance by 25 hours each day. What are the 2 ways to do it?
pd.period_range('2016-01-01 10:10', freq = '25H', periods = 10)
# Out:
# PeriodIndex(['2016-01-01 10:00', '2016-01-02 11:00', '2016-01-03 12:00',
#              '2016-01-04 13:00', '2016-01-05 14:00', '2016-01-06 15:00',
#              '2016-01-07 16:00', '2016-01-08 17:00', '2016-01-09 18:00',
#              '2016-01-10 19:00'],
#             dtype='period[25H]', freq='25H')

# %%
pd.period_range('2016-01-01 10:10', freq = '1D1H', periods = 10)
# Out:
# PeriodIndex(['2016-01-01 10:00', '2016-01-02 11:00', '2016-01-03 12:00',
#              '2016-01-04 13:00', '2016-01-05 14:00', '2016-01-06 15:00',
#              '2016-01-07 16:00', '2016-01-08 17:00', '2016-01-09 18:00',
#              '2016-01-10 19:00'],
#             dtype='period[25H]', freq='25H')

# %%
# What are some other combos you can produce?
# hint: http://pandas.pydata.org/pandas-docs/stable/timeseries.html#offset-aliases
pd.period_range('2016-01-01 10:10', freq = 'Q', periods = 10)
# Out:
# PeriodIndex(['2016Q1', '2016Q2', '2016Q3', '2016Q4', '2017Q1', '2017Q2',
#              '2017Q3', '2017Q4', '2018Q1', '2018Q2'],
#             dtype='period[Q-DEC]', freq='Q-DEC')

# %%
pd.date_range('2016-01-01 10:10', freq = 'BH', periods = 10)
# Out:
# DatetimeIndex(['2016-01-01 10:10:00', '2016-01-01 11:10:00',
#                '2016-01-01 12:10:00', '2016-01-01 13:10:00',
#                '2016-01-01 14:10:00', '2016-01-01 15:10:00',
#                '2016-01-01 16:10:00', '2016-01-04 09:10:00',
#                '2016-01-04 10:10:00', '2016-01-04 11:10:00'],
#               dtype='datetime64[ns]', freq='BH')

# %% [markdown]
# # Indexing With Time Objects

# %%
# INDEXING WITH TIME OBJECTS
# You can use these objects for indices
# Let's start with using a date range as above
rng = pd.date_range('2016 Jul 1', periods = 10, freq = 'D')
pd.Series(range(len(rng)), index = rng)
# Out:
# 2016-07-01    0
# 2016-07-02    1
# 2016-07-03    2
# 2016-07-04    3
# 2016-07-05    4
# 2016-07-06    5
# 2016-07-07    6
# 2016-07-08    7
# 2016-07-09    8
# 2016-07-10    9
# Freq: D, dtype: int64

# %%
# You can also use time period indices, in cases where it makes more sense 
# to think about your index as a time span rather than a single point in time
periods = [pd.Period('2016-01'), pd.Period('2016-02'), pd.Period('2016-03')]
ts = pd.Series(np.random.randn(len(periods)), index = periods)
ts
# Out:
# 2016-01    0.717289
# 2016-02    0.570844
# 2016-03    0.876404
# Freq: M, dtype: float64

# %%
# What type is the index for ts?
type(ts.index)
# Out:
# pandas.core.indexes.period.PeriodIndex

# %%
# Experiment with various indices
# Hint: does ts['2016'] work? 
ts[ts.index > '2016-01']
# Out:
# 2016-02    0.570844
# 2016-03    0.876404
# Freq: M, dtype: float64

# %%
# Timestamped data can be convereted to period indices with to_period and vice versa with to_timestamp
ts = pd.Series(range(10), pd.date_range('07-10-16 8:00', periods = 10, freq = 'H'))
ts
# Out:
# 2016-07-10 08:00:00    0
# 2016-07-10 09:00:00    1
# 2016-07-10 10:00:00    2
# 2016-07-10 11:00:00    3
# 2016-07-10 12:00:00    4
# 2016-07-10 13:00:00    5
# 2016-07-10 14:00:00    6
# 2016-07-10 15:00:00    7
# 2016-07-10 16:00:00    8
# 2016-07-10 17:00:00    9
# Freq: H, dtype: int64

# %%
ts_period = ts.to_period()
ts_period
# Out:
# 2016-07-10 08:00    0
# 2016-07-10 09:00    1
# 2016-07-10 10:00    2
# 2016-07-10 11:00    3
# 2016-07-10 12:00    4
# 2016-07-10 13:00    5
# 2016-07-10 14:00    6
# 2016-07-10 15:00    7
# 2016-07-10 16:00    8
# 2016-07-10 17:00    9
# Freq: H, dtype: int64

# %%
ts_period['2016-07-10 08:30':'2016-07-10 11:45'] # we have the concept of overlap with time periods
# Out:
# 2016-07-10 08:00    0
# 2016-07-10 09:00    1
# 2016-07-10 10:00    2
# 2016-07-10 11:00    3
# Freq: H, dtype: int64

# %%
ts['2016-07-10 08:30':'2016-07-10 11:45'] # we have the concept of include with timestamps
# Out:
# 2016-07-10 09:00:00    1
# 2016-07-10 10:00:00    2
# 2016-07-10 11:00:00    3
# Freq: H, dtype: int64
